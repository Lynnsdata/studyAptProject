# %%
import os
import pandas as pd
import numpy as np

# %%
df_lst = pd.read_csv('../data/주택도시보증공사_전국 신규 민간아파트 분양가격 동향.csv',encoding='cp949')
df_lst
# Out:
#      지역명                     규모구분    연도   월 분양가격(제곱미터)
# 0     서울                     모든면적  2015  10       5841
# 1     서울            전용면적 60제곱미터이하  2015  10       5652
# 2     서울   전용면적 60제곱미터초과 85제곱미터이하  2015  10       5882
# 3     서울  전용면적 85제곱미터초과 102제곱미터이하  2015  10       5721
# 4     서울           전용면적 102제곱미터초과  2015  10       5879
# ...   ..                      ...   ...  ..        ...
# 6285  제주                     모든면적  2021  11      6,860
# 6286  제주            전용면적 60제곱미터이하  2021  11        NaN
# 6287  제주   전용면적 60제곱미터초과 85제곱미터이하  2021  11      6,787
# 6288  제주  전용면적 85제곱미터초과 102제곱미터이하  2021  11      5,924
# 6289  제주           전용면적 102제곱미터초과  2021  11      6,815
#
# [6290 rows x 5 columns]

# %%
type(np.nan)
# Out:
# float

# %%
type(df_lst['분양가격(제곱미터)'])
# Out:
# pandas.core.series.Series

# %%
type(df_lst['분양가격(제곱미터)'][6289])
# Out:
# str

# %%
df_lst['분양가격(제곱미터)'] = df_lst['분양가격(제곱미터)'].str.replace(',','')

# %%
df_lst.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6290 entries, 0 to 6289
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   지역명         6290 non-null   object
#  1   규모구분        6290 non-null   object
#  2   연도          6290 non-null   int64
#  3   월           6290 non-null   int64
#  4   분양가격(제곱미터)  5812 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 245.8+ KB

# %%
pd.to_numeric(df_lst["분양가격(제곱미터)"], errors='coerce')
# Out:
# 0       5841.0
# 1       5652.0
# 2       5882.0
# 3       5721.0
# 4       5879.0
#          ...
# 6285    6860.0
# 6286       NaN
# 6287    6787.0
# 6288    5924.0
# 6289    6815.0
# Name: 분양가격(제곱미터), Length: 6290, dtype: float64

# %%
df_lst.head()
# Out:
#   지역명                     규모구분    연도   월 분양가격(제곱미터)
# 0  서울                     모든면적  2015  10       5841
# 1  서울            전용면적 60제곱미터이하  2015  10       5652
# 2  서울   전용면적 60제곱미터초과 85제곱미터이하  2015  10       5882
# 3  서울  전용면적 85제곱미터초과 102제곱미터이하  2015  10       5721
# 4  서울           전용면적 102제곱미터초과  2015  10       5879

# %%
df_lst["분양가격"] = pd.to_numeric(df_lst["분양가격(제곱미터)"], errors='coerce')
df_lst.tail()
# Out:
#      지역명                     규모구분    연도   월 분양가격(제곱미터)    분양가격
# 6285  제주                     모든면적  2021  11       6860  6860.0
# 6286  제주            전용면적 60제곱미터이하  2021  11        NaN     NaN
# 6287  제주   전용면적 60제곱미터초과 85제곱미터이하  2021  11       6787  6787.0
# 6288  제주  전용면적 85제곱미터초과 102제곱미터이하  2021  11       5924  5924.0
# 6289  제주           전용면적 102제곱미터초과  2021  11       6815  6815.0

# %%
df_lst['평당분양가격'] = df_lst.분양가격*3.3
df_lst.평당분양가격
# Out:
# 0       19275.3
# 1       18651.6
# 2       19410.6
# 3       18879.3
# 4       19400.7
#          ...
# 6285    22638.0
# 6286        NaN
# 6287    22397.1
# 6288    19549.2
# 6289    22489.5
# Name: 평당분양가격, Length: 6290, dtype: float64

# %%
df_lst.head(2)
# Out:
#   지역명           규모구분    연도   월 분양가격(제곱미터)    분양가격   평당분양가격
# 0  서울           모든면적  2015  10       5841  5841.0  19275.3
# 1  서울  전용면적 60제곱미터이하  2015  10       5652  5652.0  18651.6

# %%
df_lst.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6290 entries, 0 to 6289
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   지역명         6290 non-null   object
#  1   규모구분        6290 non-null   object
#  2   연도          6290 non-null   int64
#  3   월           6290 non-null   int64
#  4   분양가격(제곱미터)  5812 non-null   object
#  5   분양가격        5781 non-null   float64
#  6   평당분양가격      5781 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 344.1+ KB

# %%
df_lst['분양가격(제곱미터)'].describe()
# Out:
# count     5812
# unique    2261
# top
# freq        31
# Name: 분양가격(제곱미터), dtype: object

# %%
df_lst['분양가격'].unique()
# Out:
# array([5841., 5652., 5882., ..., 2908., 2928., 2943.])

# %%
df_fst = pd.read_csv('../data/전국 평균 분양가격(2013년 9월부터 2015년 8월까지).csv',encoding='cp949')

# %%
df_fst.head(3)
# Out:
#    지역  2013년12월  2014년1월  2014년2월  2014년3월  2014년4월  2014년5월  2014년6월  \
# 0  서울     18189    17925    17925    18016    18098    19446    18867
# 1  부산      8111     8111     9078     8965     9402     9501     9453
# 2  대구      8080     8080     8077     8101     8267     8274     8360
#
#    2014년7월  2014년8월  ...  2014년11월  2014년12월  2015년1월  2015년2월  2015년3월  \
# 0    18742    19274  ...     20242     20269    20670    20670    19415
# 1     9457     9411  ...      9208      9208     9204     9235     9279
# 2     8360     8370  ...      8439      8253     8327     8416     8441
#
#    2015년4월  2015년5월  2015년6월  2015년7월  2015년8월
# 0    18842    18367    18374    18152    18443
# 1     9327     9345     9515     9559     9581
# 2     8446     8568     8542     8542     8795
#
# [3 rows x 22 columns]

# %%
df_fst.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 22 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   지역        17 non-null     object
#  1   2013년12월  17 non-null     int64
#  2   2014년1월   17 non-null     int64
#  3   2014년2월   17 non-null     int64
#  4   2014년3월   17 non-null     int64
#  5   2014년4월   17 non-null     int64
#  6   2014년5월   17 non-null     int64
#  7   2014년6월   17 non-null     int64
#  8   2014년7월   17 non-null     int64
#  9   2014년8월   17 non-null     int64
#  10  2014년9월   17 non-null     int64
#  11  2014년10월  17 non-null     int64
#  12  2014년11월  17 non-null     int64
#  13  2014년12월  17 non-null     int64
#  14  2015년1월   17 non-null     int64
#  15  2015년2월   17 non-null     int64
#  16  2015년3월   17 non-null     int64
#  17  2015년4월   17 non-null     int64
#  18  2015년5월   17 non-null     int64
#  19  2015년6월   17 non-null     int64
#  20  2015년7월   17 non-null     int64
#  21  2015년8월   17 non-null     int64
# dtypes: int64(21), object(1)
# memory usage: 3.0+ KB

# %%
df_lst.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6290 entries, 0 to 6289
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   지역명         6290 non-null   object
#  1   규모구분        6290 non-null   object
#  2   연도          6290 non-null   int64
#  3   월           6290 non-null   int64
#  4   분양가격(제곱미터)  5812 non-null   object
#  5   분양가격        5781 non-null   float64
#  6   평당분양가격      5781 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 344.1+ KB

# %%
df_lst.규모구분.unique()
# Out:
# array(['모든면적', '전용면적 60제곱미터이하', '전용면적 60제곱미터초과 85제곱미터이하',
#        '전용면적 85제곱미터초과 102제곱미터이하', '전용면적 102제곱미터초과'], dtype=object)

# %%
df_lst['전용면적'] = df_lst['규모구분'].str.replace('전용면적','')
df_lst['전용면적'] = df_lst['전용면적'].str.replace('제곱미터초과','~')
df_lst['전용면적'] = df_lst['전용면적'].str.replace('제곱미터이하','')
df_lst['전용면적'] = df_lst['전용면적'].str.replace(' ','').str.strip()
df_lst['전용면적']
# Out:
# 0         모든면적
# 1           60
# 2        60~85
# 3       85~102
# 4         102~
#          ...
# 6285      모든면적
# 6286        60
# 6287     60~85
# 6288    85~102
# 6289      102~
# Name: 전용면적, Length: 6290, dtype: object

# %%
df_lst.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6290 entries, 0 to 6289
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   지역명         6290 non-null   object
#  1   규모구분        6290 non-null   object
#  2   연도          6290 non-null   int64
#  3   월           6290 non-null   int64
#  4   분양가격(제곱미터)  5812 non-null   object
#  5   분양가격        5781 non-null   float64
#  6   평당분양가격      5781 non-null   float64
#  7   전용면적        6290 non-null   object
# dtypes: float64(2), int64(2), object(4)
# memory usage: 393.2+ KB

# %%
df_lst.drop(['규모구분','분양가격(제곱미터)'],axis=1,inplace=True)

# %%
df_lst.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6290 entries, 0 to 6289
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   지역명     6290 non-null   object
#  1   연도      6290 non-null   int64
#  2   월       6290 non-null   int64
#  3   분양가격    5781 non-null   float64
#  4   평당분양가격  5781 non-null   float64
#  5   전용면적    6290 non-null   object
# dtypes: float64(2), int64(2), object(2)
# memory usage: 295.0+ KB

# %%
df_lst.groupby(['지역명']).평당분양가격.mean()
# Out:
# 지역명
# 강원     8630.984078
# 경기    13803.320270
# 경남     9821.375900
# 경북     9043.574138
# 광주    11143.459223
# 대구    13077.543490
# 대전    10581.153846
# 부산    12586.699459
# 서울    25362.470959
# 세종    10379.998095
# 울산    11297.440909
# 인천    12996.175410
# 전남     8219.511667
# 전북     8047.690164
# 제주    13085.297315
# 충남     8603.278632
# 충북     7919.892391
# Name: 평당분양가격, dtype: float64

# %%
df_lst.groupby(['전용면적']).평당분양가격.mean()
# Out:
# 전용면적
# 102~      12291.705282
# 60        11097.897199
# 60~85     11091.488952
# 85~102    11952.270987
# 모든면적      11110.922124
# Name: 평당분양가격, dtype: float64

# %%
df_lst.groupby(['전용면적','지역명']).평당분양가격.mean().unstack().round()
# Out:
# 지역명         강원       경기       경남      경북       광주       대구       대전       부산  \
# 전용면적
# 102~    9712.0  15236.0  10436.0  9834.0  12515.0  14088.0  14875.0  13392.0
# 60      8328.0  13504.0   9060.0  8560.0  10324.0  12908.0   9951.0  12080.0
# 60~85   8072.0  13046.0   9133.0  8622.0  10810.0  12890.0  10250.0  12480.0
# 85~102  8992.0  14152.0  11345.0  9782.0  11587.0  12559.0   9078.0  12450.0
# 모든면적    8110.0  13078.0   9171.0  8642.0  10925.0  12879.0  10300.0  12532.0
#
# 지역명          서울       세종       울산       인천      전남      전북       제주      충남  \
# 전용면적
# 102~    25180.0  10536.0  11523.0  15220.0  9128.0  8524.0  12774.0  9069.0
# 60      25035.0  10220.0  11210.0  12304.0  7703.0  7887.0  14199.0  8165.0
# 60~85   24315.0  10350.0  11529.0  12435.0  7918.0  7651.0  13198.0  8222.0
# 85~102  27895.0  10367.0   9904.0  12782.0  8442.0  8519.0  11200.0  9549.0
# 모든면적    24376.0  10381.0  11456.0  12361.0  7916.0  7684.0  13309.0  8202.0
#
# 지역명         충북
# 전용면적
# 102~    8479.0
# 60      7466.0
# 60~85   7599.0
# 85~102  8524.0
# 모든면적    7547.0

# %%
g = df_lst.groupby(['연도','지역명']).평당분양가격.mean()

# %%
g.loc[2018]
# Out:
# 지역명
# 강원     8219.255000
# 경기    14258.420000
# 경남     9327.670000
# 경북     8680.776923
# 광주     9526.953333
# 대구    12139.252632
# 대전    10234.106667
# 부산    12889.965000
# 서울    23202.245000
# 세종    10340.463158
# 울산    10241.400000
# 인천    11881.532143
# 전남     7929.845000
# 전북     8174.595000
# 제주    11935.968000
# 충남     8201.820000
# 충북     8149.295000
# Name: 평당분양가격, dtype: float64

# %%
g.unstack().transpose()
# Out:
# 연도        2015          2016          2017          2018          2019  \
# 지역명
# 강원    7188.060   7162.903846   7318.850000   8219.255000   8934.475000
# 경기   11060.940  11684.970000  12296.185000  14258.420000  15665.540000
# 경남    8459.220   8496.730000   8806.600000   9327.670000  10697.615789
# 경북    7464.160   7753.405000   8288.063793   8680.776923   9050.250000
# 광주    7916.700   9190.683333   9599.700000   9526.953333  12111.675000
# 대구    9018.900  10282.030000  12191.972222  12139.252632  14081.650000
# 대전    8190.600   8910.733333   9912.910526  10234.106667  12619.200000
# 부산   10377.400  10743.535000  11637.615000  12889.965000  13537.865000
# 서울   20315.680  21753.435000  21864.095000  23202.245000  28286.830000
# 세종    8765.020   8857.805000   9132.945763  10340.463158  11299.394118
# 울산    9367.600   9582.574138  10630.160870  10241.400000  10216.250000
# 인천   10976.020  11099.055000  11672.430000  11881.532143  13249.775000
# 전남    6798.880   6936.600000   7413.230000   7929.845000   8219.275862
# 전북    7110.400   6906.625000   7406.126316   8174.595000   8532.260000
# 제주    7951.075   9567.480000  12628.539623  11935.968000  11828.469231
# 충남    7689.880   7958.225000   8157.315517   8201.820000   8748.840000
# 충북    6828.800   7133.335000   7462.565000   8149.295000   7970.875000
#
# 연도           2020          2021
# 지역명
# 강원   10302.423214  10260.180000
# 경기   15106.080000  14557.140000
# 경남   10919.272222  11297.520000
# 경북    9997.693750  11181.540000
# 광주   13406.485714  13637.662500
# 대구   15314.200000  15540.600000
# 대전   11238.844737  11942.800000
# 부산   13353.010000  14030.880000
# 서울   29781.015000  29186.190000
# 세종   11628.100000  12598.740000
# 울산   12837.600000  14131.773333
# 인천   14982.990000  15751.620000
# 전남    9562.398214   9961.729412
# 전북    8559.430000   9005.088889
# 제주   14192.876923  22785.964865
# 충남    9139.380000   9789.294340
# 충북    8358.956897   8805.540000

# %%
pd.pivot_table(df_lst,index=['지역명'],values=['평당분양가격'],aggfunc='mean')
# Out:
#            평당분양가격
# 지역명
# 강원    8630.984078
# 경기   13803.320270
# 경남    9821.375900
# 경북    9043.574138
# 광주   11143.459223
# 대구   13077.543490
# 대전   10581.153846
# 부산   12586.699459
# 서울   25362.470959
# 세종   10379.998095
# 울산   11297.440909
# 인천   12996.175410
# 전남    8219.511667
# 전북    8047.690164
# 제주   13085.297315
# 충남    8603.278632
# 충북    7919.892391

# %%
pd.pivot_table(df_lst,index='전용면적',values='평당분양가격')
# Out:
#               평당분양가격
# 전용면적
# 102~    12291.705282
# 60      11097.897199
# 60~85   11091.488952
# 85~102  11952.270987
# 모든면적    11110.922124

# %%
df_lst.pivot_table(index='전용면적',columns='지역명',values='평당분양가격').round()
# Out:
# 지역명         강원       경기       경남      경북       광주       대구       대전       부산  \
# 전용면적
# 102~    9712.0  15236.0  10436.0  9834.0  12515.0  14088.0  14875.0  13392.0
# 60      8328.0  13504.0   9060.0  8560.0  10324.0  12908.0   9951.0  12080.0
# 60~85   8072.0  13046.0   9133.0  8622.0  10810.0  12890.0  10250.0  12480.0
# 85~102  8992.0  14152.0  11345.0  9782.0  11587.0  12559.0   9078.0  12450.0
# 모든면적    8110.0  13078.0   9171.0  8642.0  10925.0  12879.0  10300.0  12532.0
#
# 지역명          서울       세종       울산       인천      전남      전북       제주      충남  \
# 전용면적
# 102~    25180.0  10536.0  11523.0  15220.0  9128.0  8524.0  12774.0  9069.0
# 60      25035.0  10220.0  11210.0  12304.0  7703.0  7887.0  14199.0  8165.0
# 60~85   24315.0  10350.0  11529.0  12435.0  7918.0  7651.0  13198.0  8222.0
# 85~102  27895.0  10367.0   9904.0  12782.0  8442.0  8519.0  11200.0  9549.0
# 모든면적    24376.0  10381.0  11456.0  12361.0  7916.0  7684.0  13309.0  8202.0
#
# 지역명         충북
# 전용면적
# 102~    8479.0
# 60      7466.0
# 60~85   7599.0
# 85~102  8524.0
# 모든면적    7547.0

# %%
p = pd.pivot_table(df_lst,index=['연도','지역명'],values='평당분양가격')

# %%
p.loc[2017]
# Out:
#            평당분양가격
# 지역명
# 강원    7318.850000
# 경기   12296.185000
# 경남    8806.600000
# 경북    8288.063793
# 광주    9599.700000
# 대구   12191.972222
# 대전    9912.910526
# 부산   11637.615000
# 서울   21864.095000
# 세종    9132.945763
# 울산   10630.160870
# 인천   11672.430000
# 전남    7413.230000
# 전북    7406.126316
# 제주   12628.539623
# 충남    8157.315517
# 충북    7462.565000

# %%
import matplotlib.pyplot as plt
from matplotlib import rc
import matplotlib.font_manager as fm
import seaborn as sns

plt.rc('font', family='Malgun Gothic')
sns.set(font='Malgun Gothic', rc={'axes.unicode_minus':False}, style='darkgrid')

# %%
g = df_lst.groupby(['지역명']).평당분양가격.mean().sort_values(ascending=False)
g.plot()
# Out:
# <AxesSubplot:xlabel='지역명'>

# %%
g.plot.bar(rot=0,figsize=(10,3))
# Out:
# <AxesSubplot:xlabel='지역명'>

# %%
df_lst.groupby(['전용면적']).평당분양가격.mean().plot.bar()
# Out:
# <AxesSubplot:xlabel='전용면적'>

# %%
from matplotlib.ticker import MaxNLocator

ax = plt.figure().gca()
df_lst.groupby(['연도']).평당분양가격.mean().plot() 
ax.xaxis.set_major_locator(MaxNLocator(integer = True)) # 연도에 소숫점이 생기지 않게 하기 위함

# %%
df_lst.pivot_table(index='월',columns='연도',values='평당분양가격')
# Out:
# 연도         2015          2016          2017          2018          2019  \
# 월
# 1           NaN   9334.029630  10095.132143  10719.148000  11535.540789
# 2           NaN   9361.440000  10110.885714  10766.668000  11574.793421
# 3           NaN   9423.276923  10107.428571  10905.488000  11610.094737
# 4           NaN   9601.993902  10217.232143  10920.728571  11777.876000
# 5           NaN   9602.396341  10358.819277  11087.485714  11976.394737
# 6           NaN   9676.042683  10431.618072  10921.928571  12401.884000
# 7           NaN   9700.551220  10549.536585  10868.376316  12424.852000
# 8           NaN   9719.023171  10564.869512  10811.147368  12523.896000
# 9           NaN   9737.656098  10583.601266  10915.257692  12527.571429
# 10  9086.488889   9924.225882  10399.845570  11133.269231  12619.073077
# 11  9218.122222   9972.757143  10520.096053  11224.762025  12647.785714
# 12  9303.596296  10092.264286  10597.620000  11453.822368  12622.847368
#
# 연도          2020          2021
# 월
# 1   12718.243421  13322.601266
# 2   12717.896053  13406.730380
# 3   12739.188000  13672.062963
# 4   12954.291429  13599.018293
# 5   12993.154167  13574.320253
# 6   13167.916667  13613.600000
# 7   12997.852703  13609.284615
# 8   13226.678873  13639.971429
# 9   13275.342254  13626.942857
# 10  13151.570270  13674.100000
# 11  13271.720000  13787.696154
# 12  13285.626316           NaN

# %%
df_lst.pivot_table(index='월',columns='연도',values='평당분양가격').plot.box()
# Out:
# <AxesSubplot:>

# %%
p = df_lst.pivot_table(index='월',columns=['연도','전용면적'],values='평당분양가격')
p.plot.box(figsize=(15,3),rot=30)
# Out:
# <AxesSubplot:>

# %%
p = df_lst.pivot_table(index='연도',columns='지역명',values='평당분양가격')
p.plot(figsize=(15,3),rot=30)
plt.legend(bbox_to_anchor=(1.05,1),loc=2,borderaxespad=0.)

# %%
plt.figure(figsize=(10,3))
sns.barplot(data=df_lst, x='지역명',y='평당분양가격',ci=None)
# Out:
# <AxesSubplot:xlabel='지역명', ylabel='평당분양가격'>

# %%
sns.barplot(data=df_lst,x='연도',y='평당분양가격')
# Out:
# <AxesSubplot:xlabel='연도', ylabel='평당분양가격'>

# %%
sns.catplot(data=df_lst,x='연도',y='평당분양가격',kind='bar',col='지역명',col_wrap=4)

# %%
plt.figure(figsize=(10,5))
sns.lineplot(data=df_lst,x='연도',y='평당분양가격',hue='지역명')
plt.legend(bbox_to_anchor=(1.02,1),loc=2,borderaxespad=0.)

# %% [markdown]
# ### 필요한 정보 ( 연도 / 평당분양가격 / 지역별 )

# %%
df_lst.tail(1)
# Out:
#      지역명    연도   월    분양가격   평당분양가격  전용면적
# 6289  제주  2021  11  6815.0  22489.5  102~

# %%
df_fst.tail(1)
# Out:
#     지역  2013년12월  2014년1월  2014년2월  2014년3월  2014년4월  2014년5월  2014년6월  \
# 16  제주      7674     7900     7900     7900     7900     7900     7914
#
#     2014년7월  2014년8월  ...  2014년11월  2014년12월  2015년1월  2015년2월  2015년3월  \
# 16     7914     7914  ...      7724      7739     7739     7739     7826
#
#     2015년4월  2015년5월  2015년6월  2015년7월  2015년8월
# 16     7285     7285     7343     7343     7343
#
# [1 rows x 22 columns]

# %%
df_fst.isnull().sum()
# Out:
# 지역          0
# 2013년12월    0
# 2014년1월     0
# 2014년2월     0
# 2014년3월     0
# 2014년4월     0
# 2014년5월     0
# 2014년6월     0
# 2014년7월     0
# 2014년8월     0
# 2014년9월     0
# 2014년10월    0
# 2014년11월    0
# 2014년12월    0
# 2015년1월     0
# 2015년2월     0
# 2015년3월     0
# 2015년4월     0
# 2015년5월     0
# 2015년6월     0
# 2015년7월     0
# 2015년8월     0
# dtype: int64

# %%
df_fst = df_fst.melt(id_vars='지역',var_name='기간',value_name='평당분양가격')

# %%
df_fst.head()
# Out:
#    지역        기간  평당분양가격
# 0  서울  2013년12월   18189
# 1  부산  2013년12월    8111
# 2  대구  2013년12월    8080
# 3  인천  2013년12월   10204
# 4  광주  2013년12월    6098

# %%
df_fst.columns=['지역명','기간','평당분양가격']

# %%
def yearParser(data):
    year = int(data.split('년')[0])
    return year

# %%
yearParser('2013년12월')
# Out:
# 2013

# %%
type(yearParser('2013년12월'))
# Out:
# int

# %%
import re

# %%
# df_fst.기간.apply(lambda x : x.split('년')[0]) # 람다식
df_fst['연도'] = df_fst.기간.apply(yearParser)

# %%
df_fst['월'] = df_fst.기간.apply(lambda x : x.split('년')[1].replace('월','')) # 람다식

# %%
df_fst.head(5)
# Out:
#   지역명        기간  평당분양가격    연도   월
# 0  서울  2013년12월   18189  2013  12
# 1  부산  2013년12월    8111  2013  12
# 2  대구  2013년12월    8080  2013  12
# 3  인천  2013년12월   10204  2013  12
# 4  광주  2013년12월    6098  2013  12

# %%
df_fst.head(1)
# Out:
#   지역명        기간  평당분양가격    연도   월
# 0  서울  2013년12월   18189  2013  12

# %%
df_lst.tail(10)
# Out:
#      지역명    연도   월    분양가격   평당분양가격    전용면적
# 6280  경남  2021  11  3240.0  10692.0    모든면적
# 6281  경남  2021  11  2994.0   9880.2      60
# 6282  경남  2021  11  3227.0  10649.1   60~85
# 6283  경남  2021  11  3987.0  13157.1  85~102
# 6284  경남  2021  11  3476.0  11470.8    102~
# 6285  제주  2021  11  6860.0  22638.0    모든면적
# 6286  제주  2021  11     NaN      NaN      60
# 6287  제주  2021  11  6787.0  22397.1   60~85
# 6288  제주  2021  11  5924.0  19549.2  85~102
# 6289  제주  2021  11  6815.0  22489.5    102~

# %%
cols = ['지역명', '연도', '월', '평당분양가격']

# %%
df_lst_prepare = df_lst.loc[df_lst.전용면적=='모든면적',cols].copy()
df_fst_prepare = df_fst[cols].copy()

# %%
df_fst_prepare.shape
# Out:
# (357, 4)

# %%
df_lst_prepare.shape
# Out:
# (1258, 4)

# %%
df = pd.concat([df_fst_prepare,df_lst_prepare])

# %%
df.reset_index(drop=True,inplace=True)

# %%
from matplotlib import rc
import matplotlib.font_manager as fm
import seaborn as sns
import matplotlib.pyplot as plt

plt.rc('font', family='Malgun Gothic')
sns.set(font='Malgun Gothic', rc={'axes.unicode_minus':False}, style='darkgrid')

# %%
g.plot.bar(rot=0,figsize=(10,5))
# Out:
# <AxesSubplot:xlabel='지역명'>

# %%
from matplotlib.ticker import MaxNLocator

ax = plt.figure().gca()
df.groupby(["연도"])["평당분양가격"].mean().plot()
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

# %%
sns.catplot(data=df, x="연도", y="평당분양가격", kind="bar", col="지역명", col_wrap=4)

# %%
plt.figure(figsize=(15, 10))
sns.lineplot(data=df, x="연도", y="평당분양가격", hue="지역명")
plt.legend(bbox_to_anchor=(1.02, 1), loc=2, borderaxespad=0.)

# %%
sns.boxplot(data=df, x="연도", y="평당분양가격")
# Out:
# <AxesSubplot:xlabel='연도', ylabel='평당분양가격'>

# %%
sns.violinplot(data=df, x="연도", y="평당분양가격")
# Out:
# <AxesSubplot:xlabel='연도', ylabel='평당분양가격'>

# %%
sns.regplot(data=df, x="연도", y="평당분양가격", x_jitter=.1)
# Out:
# <AxesSubplot:xlabel='연도', ylabel='평당분양가격'>

# %%
sns.displot(data=df, x="평당분양가격", kde=True, rug=True, hue="지역명",col='지역명',col_wrap=5)

# %%
sns.pairplot(df, hue="지역명")

# %%
t = pd.pivot_table(df, index="연도", columns="지역명",values="평당분양가격").round()
plt.figure(figsize=(15, 7))
sns.heatmap(t, cmap="Blues", annot=True, fmt=".0f")
# Out:
# <AxesSubplot:xlabel='지역명', ylabel='연도'>

# %%
plt.figure(figsize=(24, 4))
sns.swarmplot(data=df, x="지역명", y="평당분양가격", hue="연도", size=2)
plt.legend(bbox_to_anchor=(1.01, 1), loc=2, borderaxespad=0.)

# %%
df
# Out:
#      지역명    연도   월   평당분양가격
# 0     서울  2013  12  18189.0
# 1     부산  2013  12   8111.0
# 2     대구  2013  12   8080.0
# 3     인천  2013  12  10204.0
# 4     광주  2013  12   6098.0
# ...   ..   ...  ..      ...
# 1610  전북  2021  11   8976.0
# 1611  전남  2021  11   9764.7
# 1612  경북  2021  11  10434.6
# 1613  경남  2021  11  10692.0
# 1614  제주  2021  11  22638.0
#
# [1615 rows x 4 columns]

# %%
df.to_csv('../data/지역별_연도별_평당_분양_가격.csv',encoding='utf-8')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1615 entries, 0 to 1614
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   지역명     1615 non-null   object
#  1   연도      1615 non-null   int64
#  2   월       1615 non-null   object
#  3   평당분양가격  1600 non-null   float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 50.6+ KB

# %%
df.지역명.unique()
# Out:
# array(['서울', '부산', '대구', '인천', '광주', '대전', '울산', '경기', '세종', '강원', '충북',
#        '충남', '전북', '전남', '경북', '경남', '제주'], dtype=object)

# %%
wkp = pd.read_csv('./data/경제활동인구_시도_handling.csv',index_col=0,encoding='utf-8')
sal = pd.read_csv('./data/월평균_임금_handling.csv',index_col=0,encoding='utf-8')
peo = pd.read_csv('./data/시도별_인구수_데이터_handling.csv',index_col=0,encoding='utf-8')

# %%
peo.행정구역.unique()
# Out:
# array(['서울특별시', '부산광역시', '대구광역시', '인천광역시', '광주광역시', '대전광역시', '울산광역시',
#        '세종특별자치시', '경기도', '강원도', '충청북도', '충청남도', '전라북도', '전라남도', '경상북도',
#        '경상남도', '제주특별자치도'], dtype=object)

# %%
loc = ['서울특별시', '부산광역시', '대구광역시', '인천광역시', '광주광역시', '대전광역시', '울산광역시',
       '세종특별자치시', '경기도', '강원도', '충청북도', '충청남도', '전라북도', '전라남도', '경상북도',
       '경상남도', '제주특별자치도']

# %%
df.지역명 = df.지역명.replace({
    '서울':'서울특별시',
    '부산':'부산광역시',
    '대구':'대구광역시',
    '인천':'인천광역시', 
    '광주':'광주광역시', 
    '대전':'대전광역시', 
    '울산':'울산광역시',       
    '세종':'세종특별자치시', 
    '경기':'경기도', 
    '강원':'강원도', 
    '충북':'충청북도',
    '충남':'충청남도', 
    '전북':'전라북도', 
    '전남':'전라남도', 
    '경북':'경상북도',
    '경남':'경상남도', 
    '제주':'제주특별자치도'
    })

# %%
df = df.rename(columns={'지역명':'행정구역'})

# %%
wkp.행정구역 = wkp.행정구역.replace({'제주도':'제주특별자치도'})

# %%
df.drop(columns='월',inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1615 entries, 0 to 1614
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   행정구역    1615 non-null   object
#  1   연도      1615 non-null   int64
#  2   평당분양가격  1600 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 38.0+ KB

# %%
wkp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 204 entries, 0 to 203
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   행정구역    204 non-null    object
#  1   년도      204 non-null    int64
#  2   인구수     204 non-null    int64
# dtypes: int64(2), object(1)
# memory usage: 6.4+ KB

# %%
wkp.년도 = wkp.년도.astype(str)

# %%
wkp.rename(columns={'년도':'연도','인구수':'경제활동인구'},inplace=True)

# %%
wkp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 204 entries, 0 to 203
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   행정구역    204 non-null    object
#  1   연도      204 non-null    object
#  2   경제활동인구  204 non-null    int64
# dtypes: int64(1), object(2)
# memory usage: 6.4+ KB

# %%
peo.rename(columns={'년도':'연도'},inplace=True)
peo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 204 entries, 0 to 203
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   행정구역    204 non-null    object
#  1   연도      204 non-null    int64
#  2   인구수     204 non-null    int64
# dtypes: int64(2), object(1)
# memory usage: 6.4+ KB

# %%
sal.rename(columns={'년도':'연도'},inplace=True)
sal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 187 entries, 0 to 186
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   행정구역    187 non-null    object
#  1   연도      187 non-null    int64
#  2   소득      187 non-null    int64
# dtypes: int64(2), object(1)
# memory usage: 5.8+ KB

# %%
df.연도 = df.연도.astype(str)

# %%
dataFrame_list = [wkp,peo,sal]

# %%
df = df.merge(wkp,how='left',on=['연도','행정구역'])
df.head(1)
# Out:
#     행정구역    연도   평당분양가격   경제활동인구
# 0  서울특별시  2013  18189.0  5355000

# %%
peo.연도 = peo.연도.astype(str)

# %%
df = df.merge(peo,how='left',on=['연도','행정구역'])
df.head(1)
# Out:
#     행정구역    연도   평당분양가격   경제활동인구      인구수
# 0  서울특별시  2013  18189.0  5355000  9990010

# %%
sal.연도 = sal.연도.astype(str)

# %%
df = df.merge(sal,how='left',on=['연도','행정구역'])
df.head(1)
# Out:
#     행정구역    연도   평당분양가격   경제활동인구      인구수   소득
# 0  서울특별시  2013  18189.0  5355000  9990010  316
